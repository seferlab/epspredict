# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import interpolate

# %%
df_actual=pd.read_csv('../Data/Actuals.csv')

df_actual = df_actual.drop(columns=['TICKER'])

df_actual = df_actual[df_actual['PENDS'] > '2014-12-31']

# %%
appl = df_actual[df_actual["OFTIC"] == "AAPL"]
appl.isna().sum()
# Out:
# OFTIC        0
# CNAME        0
# PENDS        0
# MEASURE      0
# PDICITY      0
# ANNDATS      0
# VALUE      131
# dtype: int64

# %%
#min period end date'i 2015 sonrası olan yani 2015'ten sonra başlayan
df_actual['PENDS'] = pd.to_datetime(df_actual['PENDS']) #.year kullanabilmek için datetime çevir

min_pend = df_actual.groupby('OFTIC')['PENDS'].min()

# Filter companies with a minimum announce date after 2015
companies_to_keep = min_pend[min_pend.dt.year <= 2015].reset_index()['OFTIC']

# Create a new DataFrame with only the data for the selected companies
df_actual = df_actual[df_actual['OFTIC'].isin(companies_to_keep)]

# %%
df_actual.reset_index(drop=True,inplace=True)
df_actual
# Out:
#        OFTIC            CNAME      PENDS MEASURE PDICITY     ANNDATS  \
# 0       PAYC  PAYCOM SOFTWARE 2015-03-31     EPS     QTR  2015-05-06
# 1       PAYC  PAYCOM SOFTWARE 2015-06-30     EPS     QTR  2015-08-04
# 2       PAYC  PAYCOM SOFTWARE 2015-09-30     EPS     QTR  2015-11-03
# 3       PAYC  PAYCOM SOFTWARE 2015-12-31     EPS     QTR  2016-02-09
# 4       PAYC  PAYCOM SOFTWARE 2016-03-31     EPS     QTR  2016-05-03
# ...      ...              ...        ...     ...     ...         ...
# 319468   TJX              TJX 2022-04-30     SAL     QTR  2022-05-18
# 319469   TJX              TJX 2022-07-31     SAL     QTR  2022-08-17
# 319470   TJX              TJX 2022-10-31     SAL     QTR  2022-11-16
# 319471   TJX              TJX 2023-01-31     SAL     QTR  2023-02-22
# 319472   TJX              TJX 2023-04-30     SAL     QTR  2023-05-17
#
#             VALUE
# 0           0.120
# 1           0.100
# 2           0.080
# 3           0.100
# 4           0.330
# ...           ...
# 319468  11406.474
# 319469  11843.008
# 319470  12166.286
# 319471  14520.000
# 319472  11783.000
#
# [319473 rows x 7 columns]

# %%
df_actual["MEASURE"].unique()
# Out:
# array(['EPS', 'BPS', 'CPS', 'CPX', 'CSH', 'DPS', 'EBG', 'EBI', 'EBS',
#        'EBT', 'ENT', 'FFO', 'GPS', 'GRM', 'NAV', 'NDT', 'NET', 'OPR',
#        'PRE', 'ROA', 'ROE', 'SAL'], dtype=object)

# %%
comp_list = df_actual["OFTIC"].unique()
comp_list
# Out:
# array(['PAYC', 'ANET', 'KEYS', 'MTCH', 'AAPL', 'AAP', 'ABBV', 'ABT',
#        'ADSK', 'TAP', 'CB', 'ACN', 'ADBE', 'ADI', 'ADM', 'AEP', 'AES',
#        'AFL', 'SWKS', 'HES', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'HON',
#        'ALLE', 'ALGN', 'ALK', 'ALL', 'AMAT', 'PLD', 'AMD', 'AMGN', 'AMP',
#        'AAL', 'AMT', 'AMZN', 'ANSS', 'AVGO', 'APA', 'APD', 'APH', 'ARE',
#        'ABC', 'A', 'ADP', 'AVB', 'ATVI', 'AVY', 'AWK', 'AXP', 'AZO',
#        'PNW', 'BA', 'BAX', 'BR', 'BBY', 'RHI', 'BDX', 'VZ', 'BF.B', 'BIO',
#        'BK', 'BRK.B', 'WRB', 'BLK', 'BMY', 'BSX', 'BWA', 'BXP', 'CAG',
#        'CAT', 'CBOE', 'C', 'CCL', 'CHTR', 'COST', 'STZ', 'CAH', 'CDW',
#        'CE', 'FIS', 'CF', 'CFG', 'JPM', 'CHRW', 'CVX', 'CI', 'CINF', 'CL',
#        'CLX', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMS', 'CNC', 'COF', 'CPB',
#        'CPRT', 'CPT', 'CHD', 'CRL', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTLT',
#        'CTSH', 'CMI', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DGX', 'TGT', 'DIS',
#        'DISH', 'DLR', 'DLTR', 'DHR', 'DPZ', 'DG', 'DOV', 'DOW', 'OMC',
#        'MU', 'DHI', 'DRI', 'DTE', 'DUK', 'DVN', 'MS', 'DXCM', 'EBAY',
#        'CDNS', 'ECL', 'ED', 'EFX', 'ATO', 'PKI', 'EL', 'EMN', 'EMR',
#        'ENPH', 'EOG', 'EPAM', 'EQIX', 'EQR', 'EQT', 'CZR', 'EA', 'ESS',
#        'ETN', 'ETSY', 'EW', 'EXPD', 'EXPE', 'EXR', 'COO', 'F', 'RF',
#        'FANG', 'FAST', 'FCX', 'FDS', 'FDX', 'MTB', 'FFIV', 'FISV', 'FITB',
#        'FLT', 'FMC', 'USB', 'NEE', 'FRC', 'BEN', 'FRT', 'FSLR', 'FTNT',
#        'IT', 'GD', 'IR', 'GE', 'GILD', 'GIS', 'GLW', 'GM', 'GNRC',
#        'GOOGL', 'GOOG', 'GPC', 'GPN', 'GRMN', 'GS', 'GWW', 'HAL', 'MNST',
#        'HAS', 'HBAN', 'HCA', 'HD', 'HIG', 'HII', 'HLT', 'HST', 'HOLX',
#        'CNP', 'HRL', 'HSIC', 'HSY', 'HUM', 'HPQ', 'IBM', 'ICE', 'BIIB',
#        'IDXX', 'IEX', 'IFF', 'ILMN', 'IRM', 'INTC', 'INTU', 'IP', 'IPG',
#        'INCY', 'ISRG', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR',
#        'K', 'MDLZ', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX', 'KO', 'KR',
#        'LYB', 'LEN', 'LMT', 'LKQ', 'LLY', 'LNC', 'LOW', 'LRCX', 'L',
#        'LUV', 'LVS', 'LYV', 'MAA', 'MA', 'MAS', 'AME', 'MKC', 'MCD',
#        'MCHP', 'MCK', 'MDT', 'MCO', 'CVS', 'MET', 'MGM', 'MAR', 'MKTX',
#        'MLM', 'MMC', 'MMM', 'MO', 'MHK', 'MOH', 'MOS', 'MSI', 'TMUS',
#        'MPC', 'MPWR', 'MRK', 'MRO', 'MSFT', 'ETR', 'MTD', 'MSCI', 'BAC',
#        'NCLH', 'NDAQ', 'NDSN', 'NEM', 'NFLX', 'FOXA', 'LH', 'NI', 'NKE',
#        'WFC', 'NOC', 'NOW', 'NRG', 'NSC', 'XEL', 'NTAP', 'NTRS', 'ES',
#        'NUE', 'NVDA', 'NWL', 'FOX', 'NWSA', 'NXPI', 'ODFL', 'FE', 'OKE',
#        'ON', 'ORCL', 'ORLY', 'OXY', 'COP', 'PAYX', 'PCAR', 'PCG', 'PXD',
#        'EXC', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PH', 'PHM', 'PKG', 'AON',
#        'PTC', 'PM', 'PNC', 'PNR', 'BRO', 'POOL', 'PPG', 'PPL', 'PGR',
#        'PRU', 'RE', 'PSX', 'TROW', 'PWR', 'PYPL', 'QCOM', 'QRVO', 'RL',
#        'RCL', 'REG', 'REGN', 'RMD', 'CSGP', 'ACGL', 'RJF', 'WRK', 'O',
#        'ROK', 'ROL', 'ROP', 'ROST', 'RSG', 'NVR', 'LDOS', 'SBAC', 'T',
#        'SBNY', 'SBUX', 'EIX', 'SCHW', 'SRE', 'STX', 'SEDG', 'SEE', 'PSA',
#        'SHW', 'SIVB', 'SJM', 'GEN', 'SLB', 'AOS', 'SNA', 'SNPS', 'SO',
#        'KEY', 'SPG', 'STT', 'STLD', 'TRV', 'STE', 'SYK', 'SWK', 'SYF',
#        'SYY', 'TDY', 'TECH', 'TEL', 'TER', 'TFX', 'TDG', 'TMO', 'TRGP',
#        'DVA', 'TRMB', 'TSCO', 'TSLA', 'TTWO', 'CCI', 'TXN', 'TXT', 'TYL',
#        'TSN', 'UAL', 'UDR', 'AEE', 'UHS', 'ULTA', 'UNH', 'UNP', 'UPS',
#        'URI', 'WM', 'VTR', 'VFC', 'V', 'VLO', 'VMC', 'VRSK', 'VRSN',
#        'VRTX', 'WAB', 'WBA', 'WAT', 'WDC', 'WHR', 'WMB', 'WMT', 'WEC',
#        'LNT', 'WTW', 'WST', 'WY', 'WYNN', 'XOM', 'XRAY', 'XYL', 'YUM',
#        'ZBRA', 'ZION', 'ZBH', 'ZTS', 'TJX'], dtype=object)

# %%
company_drop = ['AAL', 'AAP', 'ABBV', 'ABC', 'ABT', 'ADP', 'AFL', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'AMD', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'AON', 'AOS', 'APA', 'APD', 'APH', 'ARE', 'ATO', 'ATVI', 'AVB', 'AVY', 'BA', 'BAX', 'BDX', 'BLK', 'BMY', 'BR', 'BRO', 'BSX', 'BWA', 'BXP', 'CAH', 'CAT', 'CB', 'CBOE', 'CCI', 'CDNS', 'CDW', 'CE', 'CF', 'CHD', 'CHRW', 'CHTR', 'CI', 'CL', 'CLX', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COP', 'CPT', 'CRL', 'CSX', 'CTLT', 'CTSH', 'CVS', 'CVX', 'CZR', 'D', 'DAL', 'DD', 'DGX', 'DHI', 'DHR', 'DIS', 'DISH', 'DLR', 'DOV', 'DOW', 'DPZ', 'DVA', 'DVN', 'DXCM', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EL', 'EMN', 'EMR', 'ENPH', 'EOG', 'EPAM', 'EQIX', 'EQR', 'ES', 'ESS', 'ETN', 'ETSY', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FANG', 'FAST', 'FCX', 'FE', 'FFIV', 'FIS', 'FISV', 'FLT', 'FMC', 'FOXA', 'FRT', 'FSLR', 'FTNT', 'GD', 'GE', 'GLW', 'GM', 'GNRC', 'GOOG', 'GOOGL', 'GPC', 'GPN', 'GRMN', 'GS', 'GWW', 'HAL', 'HAS', 'HES', 'HII', 'HLT', 'HOLX', 'HON', 'HSIC', 'HST', 'HSY', 'HUM', 'IBM', 'ICE', 'IEX', 'IFF', 'ILMN', 'INTC', 'IP', 'IPG', 'IR', 'IRM', 'ISRG', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR', 'K', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KO', 'LDOS', 'LH', 'LLY', 'LMT', 'LRCX', 'LUV', 'LVS', 'LYB', 'LYV', 'MA', 'MAA', 'MAR', 'MAS', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MET', 'MHK', 'MKTX', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOH', 'MOS', 'MPC', 'MPWR', 'MRK', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTCH', 'MTD', 'NCLH', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NI', 'NOC', 'NOW', 'NSC', 'NUE', 'NVR', 'NWL', 'NWSA', 'NXPI', 'O', 'ODFL', 'OKE', 'OMC', 'ON', 'ORLY', 'OXY', 'PAYC', 'PCAR', 'PEP', 'PFE', 'PFG', 'PG', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PNR', 'PPG', 'PRU', 'PSA', 'PSX', 'PWR', 'PXD', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'RE', 'REG', 'RHI', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'RSG', 'SBAC', 'SBUX', 'SCHW', 'SEDG', 'SEE', 'SHW', 'SLB', 'SO', 'SPG', 'STE', 'STLD', 'STX', 'SWK', 'SWKS', 'SYK', 'SYY', 'T', 'TAP', 'TDG', 'TECH', 'TEL', 'TER', 'TFX', 'TMO', 'TMUS', 'TRGP', 'TROW', 'TRV', 'TSCO', 'TSLA', 'TSN', 'TTWO', 'TXN', 'TXT', 'UAL', 'UDR', 'UHS', 'UNH', 'UNP', 'UPS', 'URI', 'V', 'VFC', 'VLO', 'VMC', 'VRSK', 'VRTX', 'VTR', 'VZ', 'WAT', 'WDC', 'WHR', 'WM', 'WMB', 'WRK', 'WST', 'WTW', 'WY', 'XOM', 'XRAY', 'YUM', 'ZBH', 'ZBRA', 'ZION','AEP', 'ALL', 'ANSS', 'AWK', 'PNW', 'CMA', 'MTB', 'HCA', 'KMX', 'LKQ', 'MGM', 'XEL', 'ACGL', 'TRMB', 'VRSN', 'VRSN', 'WAB', 'ADM', 'AES', 'AIG', 'ALLE', 'AXP', 'BIO', 'BK', 'BRK.B', 'BRK.B', 'WRB', 'C', 'CFG', 'JPM', 'CINF', 'COF', 'CPRT', 'DFS', 'DTE', 'DUK', 'EQT', 'RF', 'FITB', 'USB', 'FRC', 'IT', 'GILD', 'HBAN', 'HIG', 'HRL', 'BIIB', 'IDXX', 'IDXX', 'INCY', 'LNC', 'L', 'AME', 'ETR', 'BAC', 'WFC', 'NRG', 'NTRS', 'FOX', 'FOX', 'FOX', 'PCG', 'PEG', 'PTC', 'PM', 'PNC', 'POOL', 'PPL', 'PGR', 'REGN', 'CSGP', 'SBNY', 'EIX', 'SRE', 'SIVB', 'GEN', 'SNA', 'KEY', 'STT', 'SYF', 'TDY', 'TYL', 'TYL', 'AEE', 'WEC', 'LNT', 'WYNN', 'XYL', 'ZTS']
measures = ["EPS","ROE","SAL","NET","EBI","EBT","GPS","DPS","BPS","NAV"]

df_actual = df_actual[df_actual["MEASURE"].isin(measures)]
print(df_actual["MEASURE"].unique())
print(len(company_drop))
print(len(df_actual["OFTIC"].unique()))
df_actual = df_actual[~df_actual["OFTIC"].isin(company_drop)]
df_actual
# Out:
# ['EPS' 'BPS' 'DPS' 'EBI' 'EBT' 'GPS' 'NAV' 'NET' 'ROE' 'SAL']
# 413
# 459
#        OFTIC          CNAME      PENDS MEASURE PDICITY     ANNDATS      VALUE
# 66      KEYS  KEYSIGHT TECH 2015-01-31     EPS     QTR  2015-02-19      0.560
# 67      KEYS  KEYSIGHT TECH 2015-04-30     EPS     QTR  2015-05-19      0.700
# 68      KEYS  KEYSIGHT TECH 2015-07-31     EPS     QTR  2015-08-19      0.550
# 69      KEYS  KEYSIGHT TECH 2015-10-31     EPS     QTR  2015-11-19      0.710
# 70      KEYS  KEYSIGHT TECH 2016-01-31     EPS     QTR  2016-02-18      0.550
# ...      ...            ...        ...     ...     ...         ...        ...
# 319468   TJX            TJX 2022-04-30     SAL     QTR  2022-05-18  11406.474
# 319469   TJX            TJX 2022-07-31     SAL     QTR  2022-08-17  11843.008
# 319470   TJX            TJX 2022-10-31     SAL     QTR  2022-11-16  12166.286
# 319471   TJX            TJX 2023-01-31     SAL     QTR  2023-02-22  14520.000
# 319472   TJX            TJX 2023-04-30     SAL     QTR  2023-05-17  11783.000
#
# [17505 rows x 7 columns]

# %%
df_actual["PENDS"] = pd.to_datetime(df_actual["PENDS"])


df_actual.loc[:, "QUARTER"] = df_actual["PENDS"].dt.quarter
df_actual.loc[:, "YEAR"] = df_actual["PENDS"].dt.year

# For df_actual
df_actual["QUARTER_YEAR"] = df_actual["PENDS"].dt.to_period("Q").astype(str)

# %%
condition = (df_actual["OFTIC"] == "AES") & (df_actual["MEASURE"] == "ROE")
df_actual.loc[condition]
# Out:
# Empty DataFrame
# Columns: [OFTIC, CNAME, PENDS, MEASURE, PDICITY, ANNDATS, VALUE, QUARTER, YEAR, QUARTER_YEAR]
# Index: []

# %%
df_actual[(df_actual["OFTIC"] == "PAYC") & (df_actual["MEASURE"] == "ROE")]
# Out:
# Empty DataFrame
# Columns: [OFTIC, CNAME, PENDS, MEASURE, PDICITY, ANNDATS, VALUE, QUARTER, YEAR, QUARTER_YEAR]
# Index: []

# %%
appl = df_actual[df_actual["OFTIC"] == "AAPL"]
appl.isna().sum()
# Out:
# OFTIC           0
# CNAME           0
# PENDS           0
# MEASURE         0
# PDICITY         0
# ANNDATS         0
# VALUE           0
# QUARTER         0
# YEAR            0
# QUARTER_YEAR    0
# dtype: int64

# %%
no_missing_comp = []
for ticker in comp_list:
    if df_actual[df_actual["OFTIC"] == ticker].isna().sum().sum() == 0:
        no_missing_comp.append(ticker)

# %%
no_missing_comp
# Out:
# ['PAYC',
#  'ANET',
#  'MTCH',
#  'AAPL',
#  'AAP',
#  'ABBV',
#  'ABT',
#  'TAP',
#  'CB',
#  'ACN',
#  'ADM',
#  'AEP',
#  'AES',
#  'AFL',
#  'SWKS',
#  'HES',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'HON',
#  'ALLE',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'PLD',
#  'AMD',
#  'AMGN',
#  'AMP',
#  'AAL',
#  'AMT',
#  'AMZN',
#  'ANSS',
#  'AVGO',
#  'APA',
#  'APD',
#  'APH',
#  'ARE',
#  'ABC',
#  'ADP',
#  'AVB',
#  'ATVI',
#  'AVY',
#  'AWK',
#  'AXP',
#  'PNW',
#  'BA',
#  'BAX',
#  'BR',
#  'RHI',
#  'BDX',
#  'VZ',
#  'BIO',
#  'BK',
#  'BRK.B',
#  'WRB',
#  'BLK',
#  'BMY',
#  'BSX',
#  'BWA',
#  'BXP',
#  'CAT',
#  'CBOE',
#  'C',
#  'CHTR',
#  'CAH',
#  'CDW',
#  'CE',
#  'FIS',
#  'CF',
#  'CFG',
#  'JPM',
#  'CHRW',
#  'CVX',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
#  'CMA',
#  'CMCSA',
#  'CME',
#  'CMG',
#  'CMS',
#  'CNC',
#  'COF',
#  'CPRT',
#  'CPT',
#  'CHD',
#  'CRL',
#  'CSX',
#  'CTLT',
#  'CTSH',
#  'CMI',
#  'D',
#  'DAL',
#  'DD',
#  'DFS',
#  'DGX',
#  'DIS',
#  'DISH',
#  'DLR',
#  'DHR',
#  'DPZ',
#  'DG',
#  'DOV',
#  'DOW',
#  'OMC',
#  'DHI',
#  'DTE',
#  'DUK',
#  'DVN',
#  'MS',
#  'DXCM',
#  'EBAY',
#  'CDNS',
#  'ECL',
#  'ED',
#  'EFX',
#  'ATO',
#  'PKI',
#  'EL',
#  'EMN',
#  'EMR',
#  'ENPH',
#  'EOG',
#  'EPAM',
#  'EQIX',
#  'EQR',
#  'EQT',
#  'CZR',
#  'EA',
#  'ESS',
#  'ETN',
#  'ETSY',
#  'EW',
#  'EXPD',
#  'EXPE',
#  'EXR',
#  'F',
#  'RF',
#  'FANG',
#  'FAST',
#  'FCX',
#  'FDS',
#  'MTB',
#  'FFIV',
#  'FISV',
#  'FITB',
#  'FLT',
#  'FMC',
#  'USB',
#  'NEE',
#  'FRC',
#  'FRT',
#  'FSLR',
#  'FTNT',
#  'IT',
#  'GD',
#  'IR',
#  'GE',
#  'GILD',
#  'GLW',
#  'GM',
#  'GNRC',
#  'GOOGL',
#  'GOOG',
#  'GPC',
#  'GPN',
#  'GRMN',
#  'GS',
#  'GWW',
#  'HAL',
#  'MNST',
#  'HAS',
#  'HBAN',
#  'HCA',
#  'HIG',
#  'HII',
#  'HLT',
#  'HST',
#  'HOLX',
#  'CNP',
#  'HRL',
#  'HSIC',
#  'HSY',
#  'HUM',
#  'IBM',
#  'ICE',
#  'BIIB',
#  'IDXX',
#  'IEX',
#  'IFF',
#  'ILMN',
#  'IRM',
#  'INTC',
#  'IP',
#  'IPG',
#  'INCY',
#  'ISRG',
#  'ITW',
#  'IVZ',
#  'JBHT',
#  'JCI',
#  'JKHY',
#  'JNJ',
#  'JNPR',
#  'K',
#  'MDLZ',
#  'KHC',
#  'KIM',
#  'KLAC',
#  'KMB',
#  'KMI',
#  'KMX',
#  'KO',
#  'LYB',
#  'LMT',
#  'LKQ',
#  'LLY',
#  'LNC',
#  'LRCX',
#  'L',
#  'LUV',
#  'LVS',
#  'LYV',
#  'MAA',
#  'MA',
#  'MAS',
#  'AME',
#  'MCD',
#  'MCHP',
#  'MCK',
#  'MCO',
#  'CVS',
#  'MET',
#  'MGM',
#  'MAR',
#  'MKTX',
#  'MLM',
#  'MMC',
#  'MMM',
#  'MO',
#  'MHK',
#  'MOH',
#  'MOS',
#  'MSI',
#  'TMUS',
#  'MPC',
#  'MPWR',
#  'MRK',
#  'MRO',
#  'MSFT',
#  'ETR',
#  'MTD',
#  'MSCI',
#  'BAC',
#  'NCLH',
#  'NDAQ',
#  'NEM',
#  'NFLX',
#  'FOXA',
#  'LH',
#  'NI',
#  'WFC',
#  'NOC',
#  'NOW',
#  'NRG',
#  'NSC',
#  'XEL',
#  'NTRS',
#  'ES',
#  'NUE',
#  'NWL',
#  'FOX',
#  'NWSA',
#  'NXPI',
#  'ODFL',
#  'FE',
#  'OKE',
#  'ON',
#  'ORLY',
#  'OXY',
#  'COP',
#  'PCAR',
#  'PCG',
#  'PXD',
#  'EXC',
#  'PEG',
#  'PEP',
#  'PFE',
#  'PFG',
#  'PG',
#  'PH',
#  'PHM',
#  'PKG',
#  'AON',
#  'PTC',
#  'PM',
#  'PNC',
#  'PNR',
#  'BRO',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PGR',
#  'PRU',
#  'RE',
#  'PSX',
#  'TROW',
#  'PWR',
#  'PYPL',
#  'QCOM',
#  'QRVO',
#  'RL',
#  'RCL',
#  'REG',
#  'REGN',
#  'RMD',
#  'CSGP',
#  'ACGL',
#  'RJF',
#  'WRK',
#  'O',
#  'ROK',
#  'ROL',
#  'ROP',
#  'RSG',
#  'NVR',
#  'LDOS',
#  'SBAC',
#  'T',
#  'SBNY',
#  'SBUX',
#  'EIX',
#  'SCHW',
#  'SRE',
#  'STX',
#  'SEDG',
#  'SEE',
#  'PSA',
#  'SHW',
#  'SIVB',
#  'GEN',
#  'SLB',
#  'AOS',
#  'SNA',
#  'SO',
#  'KEY',
#  'SPG',
#  'STT',
#  'STLD',
#  'TRV',
#  'STE',
#  'SYK',
#  'SWK',
#  'SYF',
#  'SYY',
#  'TDY',
#  'TECH',
#  'TEL',
#  'TER',
#  'TFX',
#  'TDG',
#  'TMO',
#  'TRGP',
#  'DVA',
#  'TRMB',
#  'TSCO',
#  'TSLA',
#  'TTWO',
#  'CCI',
#  'TXN',
#  'TXT',
#  'TYL',
#  'TSN',
#  'UAL',
#  'UDR',
#  'AEE',
#  'UHS',
#  'UNH',
#  'UNP',
#  'UPS',
#  'URI',
#  'WM',
#  'VTR',
#  'VFC',
#  'V',
#  'VLO',
#  'VMC',
#  'VRSK',
#  'VRSN',
#  'VRTX',
#  'WAB',
#  'WAT',
#  'WDC',
#  'WHR',
#  'WMB',
#  'WEC',
#  'LNT',
#  'WTW',
#  'WST',
#  'WY',
#  'WYNN',
#  'XOM',
#  'XRAY',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZION',
#  'ZBH',
#  'ZTS']

# %%
measures = df_actual["MEASURE"].unique()
companies = df_actual["OFTIC"].unique()
companies_to_drop = []

for company in companies:
    for measure in measures:
        try:
            condition = (df_actual["OFTIC"] == company) & (df_actual["MEASURE"] == measure)
            subset = df_actual.loc[condition, "VALUE"]
            mask = ~subset.isnull() # invert the mask to get the non-null values
        except Exception as e:
            print(e)
            
        if mask.any():
            try:
                # Perform interpolation
                interpolation_function = interpolate.interp1d(subset[mask].index, subset[mask].values, fill_value='extrapolate')
                df_actual.loc[condition, "VALUE"] = interpolation_function(subset.index)
                print(f"Interpolated values in {company}, {measure}.")
            except Exception as e:
                print(e)
                companies_to_drop.append(company)
                #df_actual.loc[condition, "VALUE"] = default_value
                print(f"No non-null values in {company}, {measure}.")
        else:
            companies_to_drop.append(company)
            #df_actual.loc[condition, "VALUE"] = default_value
            print(f"No non-null values in {company}, {measure}.")
# Out:
# Interpolated values in KEYS, EPS.
# Interpolated values in KEYS, BPS.
# Interpolated values in KEYS, DPS.
# Interpolated values in KEYS, EBI.
# Interpolated values in KEYS, EBT.
# Interpolated values in KEYS, GPS.
# Interpolated values in KEYS, NAV.
# Interpolated values in KEYS, NET.
# Interpolated values in KEYS, ROE.
# Interpolated values in KEYS, SAL.
# Interpolated values in AAPL, EPS.
# Interpolated values in AAPL, BPS.
# Interpolated values in AAPL, DPS.
# Interpolated values in AAPL, EBI.
# Interpolated values in AAPL, EBT.
# Interpolated values in AAPL, GPS.
# Interpolated values in AAPL, NAV.
# Interpolated values in AAPL, NET.
# Interpolated values in AAPL, ROE.
# Interpolated values in AAPL, SAL.
# Interpolated values in ADSK, EPS.
# Interpolated values in ADSK, BPS.
# Interpolated values in ADSK, DPS.
# Interpolated values in ADSK, EBI.
# Interpolated values in ADSK, EBT.
# Interpolated values in ADSK, GPS.
# Interpolated values in ADSK, NAV.
# Interpolated values in ADSK, NET.
# Interpolated values in ADSK, ROE.
# Interpolated values in ADSK, SAL.
# Interpolated values in ACN, EPS.
# Interpolated values in ACN, BPS.
# Interpolated values in ACN, DPS.
# Interpolated values in ACN, EBI.
# Interpolated values in ACN, EBT.
# Interpolated values in ACN, GPS.
# Interpolated values in ACN, NAV.
# Interpolated values in ACN, NET.
# Interpolated values in ACN, ROE.
# Interpolated values in ACN, SAL.
# Interpolated values in ADBE, EPS.
# Interpolated values in ADBE, BPS.
# Interpolated values in ADBE, DPS.
# Interpolated values in ADBE, EBI.
# Interpolated values in ADBE, EBT.
# Interpolated values in ADBE, GPS.
# Interpolated values in ADBE, NAV.
# Interpolated values in ADBE, NET.
# Interpolated values in ADBE, ROE.
# Interpolated values in ADBE, SAL.
# Interpolated values in ADI, EPS.
# Interpolated values in ADI, BPS.
# Interpolated values in ADI, DPS.
# Interpolated values in ADI, EBI.
# Interpolated values in ADI, EBT.
# Interpolated values in ADI, GPS.
# Interpolated values in ADI, NAV.
# Interpolated values in ADI, NET.
# Interpolated values in ADI, ROE.
# Interpolated values in ADI, SAL.
# Interpolated values in AMAT, EPS.
# Interpolated values in AMAT, BPS.
# Interpolated values in AMAT, DPS.
# Interpolated values in AMAT, EBI.
# Interpolated values in AMAT, EBT.
# Interpolated values in AMAT, GPS.
# Interpolated values in AMAT, NAV.
# Interpolated values in AMAT, NET.
# Interpolated values in AMAT, ROE.
# Interpolated values in AMAT, SAL.
# Interpolated values in AVGO, EPS.
# Interpolated values in AVGO, BPS.
# Interpolated values in AVGO, DPS.
# Interpolated values in AVGO, EBI.
# Interpolated values in AVGO, EBT.
# Interpolated values in AVGO, GPS.
# Interpolated values in AVGO, NAV.
# Interpolated values in AVGO, NET.
# Interpolated values in AVGO, ROE.
# Interpolated values in AVGO, SAL.
# Interpolated values in A, EPS.
# Interpolated values in A, BPS.
# Interpolated values in A, DPS.
# Interpolated values in A, EBI.
# Interpolated values in A, EBT.
# Interpolated values in A, GPS.
# Interpolated values in A, NAV.
# Interpolated values in A, NET.
# Interpolated values in A, ROE.
# Interpolated values in A, SAL.
# Interpolated values in AZO, EPS.
# Interpolated values in AZO, BPS.
# Interpolated values in AZO, DPS.
# Interpolated values in AZO, EBI.
# Interpolated values in AZO, EBT.
# Interpolated values in AZO, GPS.
# Interpolated values in AZO, NAV.
# Interpolated values in AZO, NET.
# Interpolated values in AZO, ROE.
# Interpolated values in AZO, SAL.
# Interpolated values in BBY, EPS.
# Interpolated values in BBY, BPS.
# Interpolated values in BBY, DPS.
# Interpolated values in BBY, EBI.
# Interpolated values in BBY, EBT.
# Interpolated values in BBY, GPS.
# Interpolated values in BBY, NAV.
# Interpolated values in BBY, NET.
# Interpolated values in BBY, ROE.
# Interpolated values in BBY, SAL.
# Interpolated values in BF.B, EPS.
# Interpolated values in BF.B, BPS.
# Interpolated values in BF.B, DPS.
# Interpolated values in BF.B, EBI.
# Interpolated values in BF.B, EBT.
# Interpolated values in BF.B, GPS.
# Interpolated values in BF.B, NAV.
# Interpolated values in BF.B, NET.
# Interpolated values in BF.B, ROE.
# Interpolated values in BF.B, SAL.
# Interpolated values in CAG, EPS.
# Interpolated values in CAG, BPS.
# Interpolated values in CAG, DPS.
# Interpolated values in CAG, EBI.
# Interpolated values in CAG, EBT.
# Interpolated values in CAG, GPS.
# Interpolated values in CAG, NAV.
# Interpolated values in CAG, NET.
# Interpolated values in CAG, ROE.
# Interpolated values in CAG, SAL.
# Interpolated values in CCL, EPS.
# Interpolated values in CCL, BPS.
# Interpolated values in CCL, DPS.
# Interpolated values in CCL, EBI.
# Interpolated values in CCL, EBT.
# Interpolated values in CCL, GPS.
# Interpolated values in CCL, NAV.
# Interpolated values in CCL, NET.
# Interpolated values in CCL, ROE.
# Interpolated values in CCL, SAL.
# Interpolated values in COST, EPS.
# Interpolated values in COST, BPS.
# Interpolated values in COST, DPS.
# Interpolated values in COST, EBI.
# Interpolated values in COST, EBT.
# Interpolated values in COST, GPS.
# Interpolated values in COST, NAV.
# Interpolated values in COST, NET.
# Interpolated values in COST, ROE.
# Interpolated values in COST, SAL.
# Interpolated values in STZ, EPS.
# Interpolated values in STZ, BPS.
# Interpolated values in STZ, DPS.
# Interpolated values in STZ, EBI.
# Interpolated values in STZ, EBT.
# Interpolated values in STZ, GPS.
# Interpolated values in STZ, NAV.
# Interpolated values in STZ, NET.
# Interpolated values in STZ, ROE.
# Interpolated values in STZ, SAL.
# Interpolated values in CPB, EPS.
# Interpolated values in CPB, BPS.
# Interpolated values in CPB, DPS.
# Interpolated values in CPB, EBI.
# Interpolated values in CPB, EBT.
# Interpolated values in CPB, GPS.
# Interpolated values in CPB, NAV.
# Interpolated values in CPB, NET.
# Interpolated values in CPB, ROE.
# Interpolated values in CPB, SAL.
# Interpolated values in CRM, EPS.
# Interpolated values in CRM, BPS.
# Interpolated values in CRM, DPS.
# Interpolated values in CRM, EBI.
# Interpolated values in CRM, EBT.
# Interpolated values in CRM, GPS.
# Interpolated values in CRM, NAV.
# Interpolated values in CRM, NET.
# Interpolated values in CRM, ROE.
# Interpolated values in CRM, SAL.
# Interpolated values in CSCO, EPS.
# Interpolated values in CSCO, BPS.
# Interpolated values in CSCO, DPS.
# Interpolated values in CSCO, EBI.
# Interpolated values in CSCO, EBT.
# Interpolated values in CSCO, GPS.
# Interpolated values in CSCO, NAV.
# Interpolated values in CSCO, NET.
# Interpolated values in CSCO, ROE.
# Interpolated values in CSCO, SAL.
# Interpolated values in CTAS, EPS.
# Interpolated values in CTAS, BPS.
# Interpolated values in CTAS, DPS.
# Interpolated values in CTAS, EBI.
# Interpolated values in CTAS, EBT.
# Interpolated values in CTAS, GPS.
# Interpolated values in CTAS, NAV.
# Interpolated values in CTAS, NET.
# Interpolated values in CTAS, ROE.
# Interpolated values in CTAS, SAL.
# Interpolated values in DE, EPS.
# Interpolated values in DE, BPS.
# Interpolated values in DE, DPS.
# Interpolated values in DE, EBI.
# Interpolated values in DE, EBT.
# Interpolated values in DE, GPS.
# Interpolated values in DE, NAV.
# Interpolated values in DE, NET.
# Interpolated values in DE, ROE.
# Interpolated values in DE, SAL.
# Interpolated values in TGT, EPS.
# Interpolated values in TGT, BPS.
# Interpolated values in TGT, DPS.
# Interpolated values in TGT, EBI.
# Interpolated values in TGT, EBT.
# Interpolated values in TGT, GPS.
# Interpolated values in TGT, NAV.
# Interpolated values in TGT, NET.
# Interpolated values in TGT, ROE.
# Interpolated values in TGT, SAL.
# Interpolated values in DLTR, EPS.
# Interpolated values in DLTR, BPS.
# Interpolated values in DLTR, DPS.
# Interpolated values in DLTR, EBI.
# Interpolated values in DLTR, EBT.
# Interpolated values in DLTR, GPS.
# Interpolated values in DLTR, NAV.
# Interpolated values in DLTR, NET.
# Interpolated values in DLTR, ROE.
# Interpolated values in DLTR, SAL.
# Interpolated values in DG, EPS.
# Interpolated values in DG, BPS.
# Interpolated values in DG, DPS.
# Interpolated values in DG, EBI.
# Interpolated values in DG, EBT.
# Interpolated values in DG, GPS.
# Interpolated values in DG, NAV.
# Interpolated values in DG, NET.
# Interpolated values in DG, ROE.
# Interpolated values in DG, SAL.
# Interpolated values in MU, EPS.
# Interpolated values in MU, BPS.
# Interpolated values in MU, DPS.
# Interpolated values in MU, EBI.
# Interpolated values in MU, EBT.
# Interpolated values in MU, GPS.
# Interpolated values in MU, NAV.
# Interpolated values in MU, NET.
# Interpolated values in MU, ROE.
# Interpolated values in MU, SAL.
# Interpolated values in DRI, EPS.
# Interpolated values in DRI, BPS.
# Interpolated values in DRI, DPS.
# Interpolated values in DRI, EBI.
# Interpolated values in DRI, EBT.
# Interpolated values in DRI, GPS.
# Interpolated values in DRI, NAV.
# Interpolated values in DRI, NET.
# Interpolated values in DRI, ROE.
# Interpolated values in DRI, SAL.
# Interpolated values in COO, EPS.
# Interpolated values in COO, BPS.
# Interpolated values in COO, DPS.
# Interpolated values in COO, EBI.
# Interpolated values in COO, EBT.
# Interpolated values in COO, GPS.
# Interpolated values in COO, NAV.
# Interpolated values in COO, NET.
# Interpolated values in COO, ROE.
# Interpolated values in COO, SAL.
# Interpolated values in FDS, EPS.
# Interpolated values in FDS, BPS.
# Interpolated values in FDS, DPS.
# Interpolated values in FDS, EBI.
# Interpolated values in FDS, EBT.
# Interpolated values in FDS, GPS.
# Interpolated values in FDS, NAV.
# Interpolated values in FDS, NET.
# Interpolated values in FDS, ROE.
# Interpolated values in FDS, SAL.
# Interpolated values in FDX, EPS.
# Interpolated values in FDX, BPS.
# Interpolated values in FDX, DPS.
# Interpolated values in FDX, EBI.
# Interpolated values in FDX, EBT.
# Interpolated values in FDX, GPS.
# Interpolated values in FDX, NAV.
# Interpolated values in FDX, NET.
# Interpolated values in FDX, ROE.
# Interpolated values in FDX, SAL.
# Interpolated values in BEN, EPS.
# Interpolated values in BEN, BPS.
# Interpolated values in BEN, DPS.
# Interpolated values in BEN, EBI.
# Interpolated values in BEN, EBT.
# Interpolated values in BEN, GPS.
# Interpolated values in BEN, NAV.
# Interpolated values in BEN, NET.
# Interpolated values in BEN, ROE.
# Interpolated values in BEN, SAL.
# Interpolated values in GIS, EPS.
# Interpolated values in GIS, BPS.
# Interpolated values in GIS, DPS.
# Interpolated values in GIS, EBI.
# Interpolated values in GIS, EBT.
# Interpolated values in GIS, GPS.
# Interpolated values in GIS, NAV.
# Interpolated values in GIS, NET.
# Interpolated values in GIS, ROE.
# Interpolated values in GIS, SAL.
# Interpolated values in HD, EPS.
# Interpolated values in HD, BPS.
# Interpolated values in HD, DPS.
# Interpolated values in HD, EBI.
# Interpolated values in HD, EBT.
# Interpolated values in HD, GPS.
# Interpolated values in HD, NAV.
# Interpolated values in HD, NET.
# Interpolated values in HD, ROE.
# Interpolated values in HD, SAL.
# Interpolated values in HPQ, EPS.
# Interpolated values in HPQ, BPS.
# Interpolated values in HPQ, DPS.
# Interpolated values in HPQ, EBI.
# Interpolated values in HPQ, EBT.
# Interpolated values in HPQ, GPS.
# Interpolated values in HPQ, NAV.
# Interpolated values in HPQ, NET.
# Interpolated values in HPQ, ROE.
# Interpolated values in HPQ, SAL.
# Interpolated values in INTU, EPS.
# Interpolated values in INTU, BPS.
# Interpolated values in INTU, DPS.
# Interpolated values in INTU, EBI.
# Interpolated values in INTU, EBT.
# Interpolated values in INTU, GPS.
# Interpolated values in INTU, NAV.
# Interpolated values in INTU, NET.
# Interpolated values in INTU, ROE.
# Interpolated values in INTU, SAL.
# Interpolated values in KR, EPS.
# Interpolated values in KR, BPS.
# Interpolated values in KR, DPS.
# Interpolated values in KR, EBI.
# Interpolated values in KR, EBT.
# Interpolated values in KR, GPS.
# Interpolated values in KR, NAV.
# Interpolated values in KR, NET.
# Interpolated values in KR, ROE.
# Interpolated values in KR, SAL.
# Interpolated values in LEN, EPS.
# Interpolated values in LEN, BPS.
# Interpolated values in LEN, DPS.
# Interpolated values in LEN, EBI.
# Interpolated values in LEN, EBT.
# Interpolated values in LEN, GPS.
# Interpolated values in LEN, NAV.
# Interpolated values in LEN, NET.
# Interpolated values in LEN, ROE.
# Interpolated values in LEN, SAL.
# Interpolated values in LOW, EPS.
# Interpolated values in LOW, BPS.
# Interpolated values in LOW, DPS.
# Interpolated values in LOW, EBI.
# Interpolated values in LOW, EBT.
# Interpolated values in LOW, GPS.
# Interpolated values in LOW, NAV.
# Interpolated values in LOW, NET.
# Interpolated values in LOW, ROE.
# Interpolated values in LOW, SAL.
# Interpolated values in MKC, EPS.
# Interpolated values in MKC, BPS.
# Interpolated values in MKC, DPS.
# Interpolated values in MKC, EBI.
# Interpolated values in MKC, EBT.
# Interpolated values in MKC, GPS.
# Interpolated values in MKC, NAV.
# Interpolated values in MKC, NET.
# Interpolated values in MKC, ROE.
# Interpolated values in MKC, SAL.
# Interpolated values in MDT, EPS.
# Interpolated values in MDT, BPS.
# Interpolated values in MDT, DPS.
# Interpolated values in MDT, EBI.
# Interpolated values in MDT, EBT.
# Interpolated values in MDT, GPS.
# Interpolated values in MDT, NAV.
# Interpolated values in MDT, NET.
# Interpolated values in MDT, ROE.
# Interpolated values in MDT, SAL.
# Interpolated values in NDSN, EPS.
# Interpolated values in NDSN, BPS.
# Interpolated values in NDSN, DPS.
# Interpolated values in NDSN, EBI.
# Interpolated values in NDSN, EBT.
# Interpolated values in NDSN, GPS.
# Interpolated values in NDSN, NAV.
# Interpolated values in NDSN, NET.
# Interpolated values in NDSN, ROE.
# Interpolated values in NDSN, SAL.
# Interpolated values in NKE, EPS.
# Interpolated values in NKE, BPS.
# Interpolated values in NKE, DPS.
# Interpolated values in NKE, EBI.
# Interpolated values in NKE, EBT.
# Interpolated values in NKE, GPS.
# Interpolated values in NKE, NAV.
# Interpolated values in NKE, NET.
# Interpolated values in NKE, ROE.
# Interpolated values in NKE, SAL.
# Interpolated values in NTAP, EPS.
# Interpolated values in NTAP, BPS.
# Interpolated values in NTAP, DPS.
# Interpolated values in NTAP, EBI.
# Interpolated values in NTAP, EBT.
# Interpolated values in NTAP, GPS.
# Interpolated values in NTAP, NAV.
# Interpolated values in NTAP, NET.
# Interpolated values in NTAP, ROE.
# Interpolated values in NTAP, SAL.
# Interpolated values in NVDA, EPS.
# Interpolated values in NVDA, BPS.
# Interpolated values in NVDA, DPS.
# Interpolated values in NVDA, EBI.
# Interpolated values in NVDA, EBT.
# Interpolated values in NVDA, GPS.
# Interpolated values in NVDA, NAV.
# Interpolated values in NVDA, NET.
# Interpolated values in NVDA, ROE.
# Interpolated values in NVDA, SAL.
# Interpolated values in ORCL, EPS.
# Interpolated values in ORCL, BPS.
# Interpolated values in ORCL, DPS.
# Interpolated values in ORCL, EBI.
# Interpolated values in ORCL, EBT.
# Interpolated values in ORCL, GPS.
# Interpolated values in ORCL, NAV.
# Interpolated values in ORCL, NET.
# Interpolated values in ORCL, ROE.
# Interpolated values in ORCL, SAL.
# Interpolated values in PAYX, EPS.
# Interpolated values in PAYX, BPS.
# Interpolated values in PAYX, DPS.
# Interpolated values in PAYX, EBI.
# Interpolated values in PAYX, EBT.
# Interpolated values in PAYX, GPS.
# Interpolated values in PAYX, NAV.
# Interpolated values in PAYX, NET.
# Interpolated values in PAYX, ROE.
# Interpolated values in PAYX, SAL.
# Interpolated values in ROST, EPS.
# Interpolated values in ROST, BPS.
# Interpolated values in ROST, DPS.
# Interpolated values in ROST, EBI.
# Interpolated values in ROST, EBT.
# Interpolated values in ROST, GPS.
# Interpolated values in ROST, NAV.
# Interpolated values in ROST, NET.
# Interpolated values in ROST, ROE.
# Interpolated values in ROST, SAL.
# Interpolated values in SJM, EPS.
# Interpolated values in SJM, BPS.
# Interpolated values in SJM, DPS.
# Interpolated values in SJM, EBI.
# Interpolated values in SJM, EBT.
# Interpolated values in SJM, GPS.
# Interpolated values in SJM, NAV.
# Interpolated values in SJM, NET.
# Interpolated values in SJM, ROE.
# Interpolated values in SJM, SAL.
# Interpolated values in SNPS, EPS.
# Interpolated values in SNPS, BPS.
# Interpolated values in SNPS, DPS.
# Interpolated values in SNPS, EBI.
# Interpolated values in SNPS, EBT.
# Interpolated values in SNPS, GPS.
# Interpolated values in SNPS, NAV.
# Interpolated values in SNPS, NET.
# Interpolated values in SNPS, ROE.
# Interpolated values in SNPS, SAL.
# Interpolated values in ULTA, EPS.
# Interpolated values in ULTA, BPS.
# Interpolated values in ULTA, DPS.
# Interpolated values in ULTA, EBI.
# Interpolated values in ULTA, EBT.
# Interpolated values in ULTA, GPS.
# Interpolated values in ULTA, NAV.
# Interpolated values in ULTA, NET.
# Interpolated values in ULTA, ROE.
# Interpolated values in ULTA, SAL.
# Interpolated values in WBA, EPS.
# Interpolated values in WBA, BPS.
# Interpolated values in WBA, DPS.
# Interpolated values in WBA, EBI.
# Interpolated values in WBA, EBT.
# Interpolated values in WBA, GPS.
# Interpolated values in WBA, NAV.
# Interpolated values in WBA, NET.
# Interpolated values in WBA, ROE.
# Interpolated values in WBA, SAL.
# Interpolated values in WMT, EPS.
# Interpolated values in WMT, BPS.
# Interpolated values in WMT, DPS.
# Interpolated values in WMT, EBI.
# Interpolated values in WMT, EBT.
# Interpolated values in WMT, GPS.
# Interpolated values in WMT, NAV.
# Interpolated values in WMT, NET.
# Interpolated values in WMT, ROE.
# Interpolated values in WMT, SAL.
# Interpolated values in TJX, EPS.
# Interpolated values in TJX, BPS.
# Interpolated values in TJX, DPS.
# Interpolated values in TJX, EBI.
# Interpolated values in TJX, EBT.
# Interpolated values in TJX, GPS.
# Interpolated values in TJX, NAV.
# Interpolated values in TJX, NET.
# Interpolated values in TJX, ROE.
# Interpolated values in TJX, SAL.

# %%
print(len(companies_to_drop))
#df_actual = df_actual[~df_actual['OFTIC'].isin(companies_to_drop)]
print(companies_to_drop)
# Out:
# 0
# []

# %%
df_actual.isnull().sum()
# Out:
# OFTIC           0
# CNAME           0
# PENDS           0
# MEASURE         0
# PDICITY         0
# ANNDATS         0
# VALUE           0
# QUARTER         0
# YEAR            0
# QUARTER_YEAR    0
# dtype: int64

# %%
# Drawing value-pends graph for one company and all measure

def draw_measure_pends(company, df):
    unique_measures = df["MEASURE"].unique()

    num_measures = len(unique_measures)
    num_cols = 3  
    num_rows = (num_measures + num_cols - 1) // num_cols  

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 25))

    for i, measure in enumerate(unique_measures):
        row, col = i // num_cols, i % num_cols
        x = df[(df['OFTIC'] == company) & (df['MEASURE'] == measure)]

        if num_rows == 1:
            axes[col].plot(x['PENDS'], x['VALUE'])
            axes[col].set_xlabel('Quarter')
            axes[col].set_ylabel('Ratio')
            axes[col].set_title(f'{measure} - Quarter Graph')
        else:
            axes[row, col].plot(x['PENDS'], x['VALUE'])
            axes[row, col].set_xlabel('Quarter')
            axes[row, col].set_ylabel('Ratio')
            axes[row, col].set_title(f'{measure} - Quarter Graph')

    for i in range(num_measures, num_rows * num_cols):
        fig.delaxes(axes.flatten()[i])

    plt.tight_layout()

    plt.show()

# %%
draw_measure_pends("GOOGL",df_actual)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 draw_measure_pends("GOOGL",df_actual)
#
# Cell In[58], line 32, in draw_measure_pends(company, df)
#      28     fig.delaxes(axes.flatten()[i])
#      30 plt.tight_layout()
# ---> 32 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/anaconda3/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2155     # we do this instead of `self.figure.draw_without_rendering`
#    2156     # so that we can inject the orientation
#    2157     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2158         self.figure.draw(renderer)
#    2159 if bbox_inches:
#    2160     if bbox_inches == "tight":
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1394, in Axis.draw(self, renderer, *args, **kwargs)
#    1391     tick.draw(renderer)
#    1393 # Shift label away from axes to avoid overlapping ticklabels.
# -> 1394 self._update_label_position(renderer)
#    1395 self.label.draw(renderer)
#    1397 self._update_offset_text_position(tlb1, tlb2)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:2368, in XAxis._update_label_position(self, renderer)
#    2364     return
#    2366 # get bounding boxes for this axis and any siblings
#    2367 # that have been set by `fig.align_xlabels()`
# -> 2368 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2370 x, y = self.label.get_position()
#    2371 if self.label_position == 'bottom':
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:2161, in Axis._get_tick_boxes_siblings(self, renderer)
#    2159 axis = ax._axis_map[name]
#    2160 ticks_to_draw = axis._update_ticks()
# -> 2161 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2162 bboxes.extend(tlb)
#    2163 bboxes2.extend(tlb2)
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1315, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1313 if renderer is None:
#    1314     renderer = self.figure._get_renderer()
# -> 1315 return ([tick.label1.get_window_extent(renderer)
#    1316          for tick in ticks if tick.label1.get_visible()],
#    1317         [tick.label2.get_window_extent(renderer)
#    1318          for tick in ticks if tick.label2.get_visible()])
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1315, in <listcomp>(.0)
#    1313 if renderer is None:
#    1314     renderer = self.figure._get_renderer()
# -> 1315 return ([tick.label1.get_window_extent(renderer)
#    1316          for tick in ticks if tick.label1.get_visible()],
#    1317         [tick.label2.get_window_extent(renderer)
#    1318          for tick in ticks if tick.label2.get_visible()])
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/text.py:956, in Text.get_window_extent(self, renderer, dpi)
#     951     raise RuntimeError(
#     952         "Cannot get window extent of text w/o renderer. You likely "
#     953         "want to call 'figure.draw_without_rendering()' first.")
#     955 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 956     bbox, info, descent = self._get_layout(self._renderer)
#     957     x, y = self.get_unitless_position()
#     958     x, y = self.get_transform().transform((x, y))
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/text.py:381, in Text._get_layout(self, renderer)
#     379 clean_line, ismath = self._preprocess_math(line)
#     380 if clean_line:
# --> 381     w, h, d = _get_text_metrics_with_cache(
#     382         renderer, clean_line, self._fontproperties,
#     383         ismath=ismath, dpi=self.figure.dpi)
#     384 else:
#     385     w = h = d = 0
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# KeyboardInterrupt:

# %%
df_actual
# Out:
#        OFTIC          CNAME      PENDS MEASURE PDICITY     ANNDATS      VALUE  \
# 66      KEYS  KEYSIGHT TECH 2015-01-31     EPS     QTR  2015-02-19      0.560
# 67      KEYS  KEYSIGHT TECH 2015-04-30     EPS     QTR  2015-05-19      0.700
# 68      KEYS  KEYSIGHT TECH 2015-07-31     EPS     QTR  2015-08-19      0.550
# 69      KEYS  KEYSIGHT TECH 2015-10-31     EPS     QTR  2015-11-19      0.710
# 70      KEYS  KEYSIGHT TECH 2016-01-31     EPS     QTR  2016-02-18      0.550
# ...      ...            ...        ...     ...     ...         ...        ...
# 319468   TJX            TJX 2022-04-30     SAL     QTR  2022-05-18  11406.474
# 319469   TJX            TJX 2022-07-31     SAL     QTR  2022-08-17  11843.008
# 319470   TJX            TJX 2022-10-31     SAL     QTR  2022-11-16  12166.286
# 319471   TJX            TJX 2023-01-31     SAL     QTR  2023-02-22  14520.000
# 319472   TJX            TJX 2023-04-30     SAL     QTR  2023-05-17  11783.000
#
#         QUARTER  YEAR QUARTER_YEAR
# 66            1  2015       2015Q1
# 67            2  2015       2015Q2
# 68            3  2015       2015Q3
# 69            4  2015       2015Q4
# 70            1  2016       2016Q1
# ...         ...   ...          ...
# 319468        2  2022       2022Q2
# 319469        3  2022       2022Q3
# 319470        4  2022       2022Q4
# 319471        1  2023       2023Q1
# 319472        2  2023       2023Q2
#
# [17505 rows x 10 columns]

# %%
df_actual.to_csv("interpolated_actuals.csv", index=False)
